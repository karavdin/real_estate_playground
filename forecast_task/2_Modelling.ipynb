# %%
import sys

import pandas as pd
import numpy as np
import datetime

from sklearn.preprocessing import OrdinalEncoder
from sklearn.pipeline import Pipeline

# from cyclic_boosting import binning, flags, CBPoissonRegressor, observers, common_smoothers
# from cyclic_boosting.smoothing.onedim import SeasonalSmoother, IsotonicRegressor
# from cyclic_boosting.plots import plot_analysis
# from cyclic_boosting.pipelines import pipeline_CBPoissonRegressor

import timeseries_plots as tsp
import kpi_calculation as kpi
from sklearn.preprocessing import LabelEncoder
# %matplotlib inline 

# from prophet import Prophet

# %% [markdown]
# # Load data

# %%
df= pd.read_csv('forecasting_cleaned.csv',parse_dates=['DATE'])

# %%
df.sample(5)
# Out:
#             DATE   PRICE  SPACE SPACE_binned                     CATEGORIES  \
# 10512 2019-05-29  1500.0   94.0    (50, 100]  APARTMENT, DUPLEX, MAISONETTE
# 2657  2018-05-16  3200.0  120.0   (100, 150]          APARTMENT, ATTIC_FLAT
# 4271  2018-07-28  1920.0   96.0    (50, 100]                APARTMENT, FLAT
# 7423  2018-12-18  1100.0   20.0      (0, 50]              APARTMENT, STUDIO
# 24651 2021-05-26  1240.0   51.0    (50, 100]                APARTMENT, FLAT
#
#        median_PRICE_CATEGORY_SPACE_binned_DATE  CATEGORY_N_DATES
# 10512                                   1500.0               451
# 2657                                    2650.0               305
# 4271                                    2210.0              1370
# 7423                                    1100.0               224
# 24651                                   1395.0              1370

# %% [markdown]
# # Baseline

# %% [markdown]
# From EDA we know that median price per category in space bins does not change a lot with time. Let's use it as baseline

# %%
df['total'] = 'Total'
df['C_DATE'] = df['DATE']

# %%
df_base = df[df['C_DATE']<='2020-12-31'].groupby(['CATEGORIES','SPACE_binned']).agg({'median_PRICE_CATEGORY_SPACE_binned_DATE':'median'}).reset_index()
df_base.rename(columns={'median_PRICE_CATEGORY_SPACE_binned_DATE':'BASELINE'}, inplace=True)
df = df.merge(df_base,on=['CATEGORIES','SPACE_binned'],how='left')

# %%
df[['DATE','PRICE','BASELINE']].sample(10)
# Out:
#             DATE   PRICE  BASELINE
# 8283  2019-02-04  1750.0    1575.0
# 4638  2018-08-16  2640.0    2390.0
# 20779 2020-11-13   650.0     855.0
# 13360 2019-10-28  1377.0    1400.0
# 11683 2019-07-31  1950.0    1400.0
# 20950 2020-11-20  1240.0    1400.0
# 11453 2019-07-18  1280.0    1400.0
# 297   2018-01-17  1440.0    1400.0
# 28443 2021-12-03  2180.0    1400.0
# 1591  2018-03-22  1070.0     855.0

# %%
tsp.plot_weekly_per_agg(df,actuals_col='PRICE',var_cols=['BASELINE'], agg_col='total', 
                           agg='median', limit_n_plots=3, title_text='',
                          date_from='2021-01-01',date_upto='2021-12-31',plot_two_years_ago=False,plot_last_year=True)
# Out:
# alt.ConcatChart(...)

# %% [markdown]
# #### As expected the baseline based on median is a bit below average prices

# %%
tsp.plot_weekly_per_agg(df,actuals_col='PRICE',var_cols=['BASELINE'], agg_col='CATEGORIES', 
                           agg='median', limit_n_plots=3, title_text='',
                          date_from='2021-01-01',date_upto='2021-12-31',plot_two_years_ago=True,plot_last_year=True)
# Out:
# alt.ConcatChart(...)
# alt.ConcatChart(...)

# %% [markdown]
# # ML model

# %% [markdown]
# ## Data enchantments

# %%
df = tsp.enrich_day(df,time_col='DATE')

# %%
df_agg_prices = df.groupby(['CATEGORIES','SPACE_binned','YEAR']).agg({'median_PRICE_CATEGORY_SPACE_binned_DATE':'median'}).reset_index()
df_agg_prices['next_YEAR'] = df_agg_prices['YEAR']+1
df_agg_prices.drop(columns=['YEAR'],inplace=True)
df_agg_prices = df_agg_prices.rename(columns={'median_PRICE_CATEGORY_SPACE_binned_DATE':'median_PRICE_CATEGORY_SPACE_binned_last_YEAR','next_YEAR':'YEAR'})

# %%
df = df.merge(df_agg_prices, on=['CATEGORIES','SPACE_binned','YEAR'], how='left')
df.head(3).T
# Out:
#                                                                       0  \
# DATE                                                2018-01-01 00:00:00
# PRICE                                                            3000.0
# SPACE                                                              70.0
# SPACE_binned                                                  (50, 100]
# CATEGORIES                                    APARTMENT, FURNISHED_FLAT
# median_PRICE_CATEGORY_SPACE_binned_DATE                          3000.0
# CATEGORY_N_DATES                                                    996
# total                                                             Total
# C_DATE                                              2018-01-01 00:00:00
# BASELINE                                                         2250.0
# ISODAY                                                                1
# WEEKDAY                                                               0
# WEEKDAY_NAME                                                     Monday
# THIS_WEEK_MONDAY                                    2018-01-01 00:00:00
# YEAR                                                               2018
# WEEK                                                                  1
# MONTH_DAY                                                             1
# MONTH                                                                 1
# WEEK_OF_MONTH                                                         0
# TIMEDELTA                                                             0
# median_PRICE_CATEGORY_SPACE_binned_last_YEAR                        NaN
#
#                                                                 1  \
# DATE                                          2018-01-02 00:00:00
# PRICE                                                      1510.0
# SPACE                                                        61.0
# SPACE_binned                                            (50, 100]
# CATEGORIES                                        APARTMENT, FLAT
# median_PRICE_CATEGORY_SPACE_binned_DATE                    1430.0
# CATEGORY_N_DATES                                             1370
# total                                                       Total
# C_DATE                                        2018-01-02 00:00:00
# BASELINE                                                   1400.0
# ISODAY                                                          2
# WEEKDAY                                                         1
# WEEKDAY_NAME                                              Tuesday
# THIS_WEEK_MONDAY                              2018-01-01 00:00:00
# YEAR                                                         2018
# WEEK                                                            1
# MONTH_DAY                                                       2
# MONTH                                                           1
# WEEK_OF_MONTH                                                   0
# TIMEDELTA                                                       0
# median_PRICE_CATEGORY_SPACE_binned_last_YEAR                  NaN
#
#                                                                 2
# DATE                                          2018-01-02 00:00:00
# PRICE                                                       980.0
# SPACE                                                        54.0
# SPACE_binned                                            (50, 100]
# CATEGORIES                                        APARTMENT, FLAT
# median_PRICE_CATEGORY_SPACE_binned_DATE                    1430.0
# CATEGORY_N_DATES                                             1370
# total                                                       Total
# C_DATE                                        2018-01-02 00:00:00
# BASELINE                                                   1400.0
# ISODAY                                                          2
# WEEKDAY                                                         1
# WEEKDAY_NAME                                              Tuesday
# THIS_WEEK_MONDAY                              2018-01-01 00:00:00
# YEAR                                                         2018
# WEEK                                                            1
# MONTH_DAY                                                       2
# MONTH                                                           1
# WEEK_OF_MONTH                                                   0
# TIMEDELTA                                                       0
# median_PRICE_CATEGORY_SPACE_binned_last_YEAR                  NaN

# %%
# Creating a instance of label Encoder.
le = LabelEncoder()
# Using .fit_transform function to fit label
# encoder and return encoded label
df['CATEGORIES_ID'] = le.fit_transform(df['CATEGORIES'])

# %% [markdown]
# ## Modeling

# %%
df_train = df.loc[df['DATE']<='2020-12-31']
df_test = df.loc[df['DATE']>'2020-12-31']

# %%
y_train = np.asarray(df_train['PRICE'])
y_test = np.asarray(df_test['PRICE'])
obs_cols = ['PRICE','THIS_WEEK_MONDAY','BASELINE','median_PRICE_CATEGORY_SPACE_binned_DATE',
            'SPACE_binned','CATEGORY_N_DATES','CATEGORIES','DATE','C_DATE','WEEKDAY_NAME','total']
X_train = df_train.drop(columns=obs_cols)
X_test = df_test.drop(columns=obs_cols)
X_test_org = X_test.copy()

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
# Setup XGBoost hyperparameter grid
xgb_param_grid = {"learning_rate": [0.05, 0.1, 0.2], # Step size shrinkage used in update to prevents overfitting.
                  "max_depth"        : [6, 8, 9, 10], # Maximum depth of a tree. 
                  "min_child_weight" : [1, 3, 5, 7], # Minimum number of instances required in a child node
                  "gamma"            : [0.0, 0.1, 0.2, 0.3], # Minimum loss reduction required to make a further partition on a leaf node of the tree.
                  "colsample_bytree" : [0.3, 0.4, 0.6, 0.8] # Number of features supplied to a tree
}

# # Setup XGBoost hyperparameter grid
# xgb_param_grid = {"learning_rate": [0.05], # Step size shrinkage used in update to prevents overfitting.
#                   "max_depth"        : [6], # Maximum depth of a tree. 
#                   "min_child_weight" : [1], # Minimum number of instances required in a child node
#                   "gamma"            : [0.0, 0.1], # Minimum loss reduction required to make a further partition on a leaf node of the tree.
#                   "colsample_bytree" : [0.3] # Number of features supplied to a tree
# }

# Instantiate XGBoost regressor
xgb_reg = xgb.XGBRegressor(seed = 42, objective ='reg:absoluteerror')

# Setup GridSearchCV
xgb_reg_grid = GridSearchCV(estimator = xgb_reg, param_grid = xgb_param_grid, cv=5, n_jobs=-1, verbose=0) 

# Fit Grid Search on training dataset
xgb_reg_grid.fit(X_train, y_train)

# Get best model (based on best parameters) and predict on test set
best_xgb_reg = xgb_reg_grid.best_estimator_
y_pred_test = best_xgb_reg.predict(X_test)

# %% [markdown]
# ## KPIs

# %%
df_test['ML FORECAST'] = y_pred_test

# %%
df_evl = df.copy()
df_evl = df_evl.merge(df_test[['DATE','SPACE','CATEGORIES','ML FORECAST']],on=['DATE','SPACE','CATEGORIES',],how='left')
df_evl['total'] = 'Total'
df_evl['C_DATE'] = df_evl['DATE']

# %%
tsp.plot_weekly_per_agg(df_evl,actuals_col='PRICE',var_cols=['BASELINE','ML FORECAST'], agg_col='total', 
                           agg='median', limit_n_plots=3, title_text='',
                          date_from='2021-01-01',date_upto='2021-12-31',plot_two_years_ago=False,plot_last_year=True)
# Out:
# alt.ConcatChart(...)

# %%
tsp.plot_weekly_per_agg(df_evl,actuals_col='PRICE',var_cols=['BASELINE','ML FORECAST'], agg_col='total', 
                           agg='max', limit_n_plots=3, title_text='',
                          date_from='2021-01-01',date_upto='2021-12-31',plot_two_years_ago=False,plot_last_year=True)
# Out:
# alt.ConcatChart(...)

# %%
tsp.plot_weekly_per_agg(df_evl,actuals_col='PRICE',var_cols=['BASELINE','ML FORECAST'], agg_col='total', 
                           agg='min', limit_n_plots=3, title_text='',
                          date_from='2021-01-01',date_upto='2021-12-31',plot_two_years_ago=False,plot_last_year=True)
# Out:
# alt.ConcatChart(...)

# %%
df_evl[df_evl['C_DATE']>df_test['DATE'].min()][['DATE','SPACE','CATEGORIES','PRICE','ML FORECAST','BASELINE']].sample(3)
# Out:
#             DATE  SPACE       CATEGORIES   PRICE  ML FORECAST  BASELINE
# 30681 2021-12-17   63.0  APARTMENT, FLAT  1390.0  1267.189941    1400.0
# 29576 2021-11-03   57.0  APARTMENT, FLAT  1100.0  1178.774780    1400.0
# 25220 2021-05-11  120.0  APARTMENT, FLAT  2270.0  2230.418945    2390.0

# %%
kpi.KPI_per_agg_var(df_test,var='total',limit=5,target_name='PRICE',pred_name='ML FORECAST',pred_name_comp='BASELINE',product_col='CATEGORIES',
                label='Total | MLForecast | Week-Category',granularity_list=['WEEK','CATEGORIES'],
                    pred_from=df_test['DATE'].min().date(),pred_upto=df_test['DATE'].max().date())
# Out:
# <style type="text/css">
# #T_29995_row0_col6, #T_29995_row0_col7, #T_29995_row1_col6, #T_29995_row1_col7 {
#   color: #E75424;
# }
# </style>
# <table id="T_29995">
#   <caption>Total | MLForecast | Week-Category | predictions from 2021-01-01 to 2021-12-31</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29995_level0_col0" class="col_heading level0 col0" >Total Actuals</th>
#       <th id="T_29995_level0_col1" class="col_heading level0 col1" >Total Predictions</th>
#       <th id="T_29995_level0_col2" class="col_heading level0 col2" >% predictions for 0 actuals</th>
#       <th id="T_29995_level0_col3" class="col_heading level0 col3" >Categories</th>
#       <th id="T_29995_level0_col4" class="col_heading level0 col4" >Mean Actuals</th>
#       <th id="T_29995_level0_col5" class="col_heading level0 col5" >Mean Predictions</th>
#       <th id="T_29995_level0_col6" class="col_heading level0 col6" >MD</th>
#       <th id="T_29995_level0_col7" class="col_heading level0 col7" >Bias</th>
#       <th id="T_29995_level0_col8" class="col_heading level0 col8" >RMAD</th>
#       <th id="T_29995_level0_col9" class="col_heading level0 col9" >RMSE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >total</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29995_level0_row0" class="row_heading level0 row0" >ML FORECAST Total</th>
#       <td id="T_29995_row0_col0" class="data row0 col0" >11,655,884</td>
#       <td id="T_29995_row0_col1" class="data row0 col1" >11,307,295</td>
#       <td id="T_29995_row0_col2" class="data row0 col2" >0.0%</td>
#       <td id="T_29995_row0_col3" class="data row0 col3" >19</td>
#       <td id="T_29995_row0_col4" class="data row0 col4" >21,827.50</td>
#       <td id="T_29995_row0_col5" class="data row0 col5" >21,174.71</td>
#       <td id="T_29995_row0_col6" class="data row0 col6" >-652.79</td>
#       <td id="T_29995_row0_col7" class="data row0 col7" >-0.03</td>
#       <td id="T_29995_row0_col8" class="data row0 col8" >6.5%</td>
#       <td id="T_29995_row0_col9" class="data row0 col9" >3,781.26</td>
#     </tr>
#     <tr>
#       <th id="T_29995_level0_row1" class="row_heading level0 row1" >BASELINE Total</th>
#       <td id="T_29995_row1_col0" class="data row1 col0" >11,655,884</td>
#       <td id="T_29995_row1_col1" class="data row1 col1" >11,222,208</td>
#       <td id="T_29995_row1_col2" class="data row1 col2" >0.0%</td>
#       <td id="T_29995_row1_col3" class="data row1 col3" >19</td>
#       <td id="T_29995_row1_col4" class="data row1 col4" >21,827.50</td>
#       <td id="T_29995_row1_col5" class="data row1 col5" >21,015.37</td>
#       <td id="T_29995_row1_col6" class="data row1 col6" >-812.13</td>
#       <td id="T_29995_row1_col7" class="data row1 col7" >-0.04</td>
#       <td id="T_29995_row1_col8" class="data row1 col8" >7.7%</td>
#       <td id="T_29995_row1_col9" class="data row1 col9" >4,215.51</td>
#     </tr>
#   </tbody>
# </table>

# %%
kpi.KPI_per_agg_var(df_test,var='CATEGORIES',limit=3,target_name='PRICE',pred_name='ML FORECAST',pred_name_comp='BASELINE',product_col='CATEGORIES',
                label='Total | ML Forecast | Week-Category',granularity_list=['WEEK','CATEGORIES'],
                    pred_from=df_test['DATE'].min().date(),pred_upto=df_test['DATE'].max().date())
# Out:
# <style type="text/css">
# #T_169a1_row0_col6, #T_169a1_row0_col7, #T_169a1_row1_col6, #T_169a1_row1_col7, #T_169a1_row4_col6, #T_169a1_row4_col7, #T_169a1_row5_col6, #T_169a1_row5_col7 {
#   color: #E75424;
# }
# #T_169a1_row2_col6, #T_169a1_row2_col7, #T_169a1_row3_col6, #T_169a1_row3_col7 {
#   color: #993399;
# }
# </style>
# <table id="T_169a1">
#   <caption>Total | ML Forecast | Week-Category | predictions from 2021-01-01 to 2021-12-31</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_169a1_level0_col0" class="col_heading level0 col0" >Total Actuals</th>
#       <th id="T_169a1_level0_col1" class="col_heading level0 col1" >Total Predictions</th>
#       <th id="T_169a1_level0_col2" class="col_heading level0 col2" >% predictions for 0 actuals</th>
#       <th id="T_169a1_level0_col3" class="col_heading level0 col3" >Categories</th>
#       <th id="T_169a1_level0_col4" class="col_heading level0 col4" >Mean Actuals</th>
#       <th id="T_169a1_level0_col5" class="col_heading level0 col5" >Mean Predictions</th>
#       <th id="T_169a1_level0_col6" class="col_heading level0 col6" >MD</th>
#       <th id="T_169a1_level0_col7" class="col_heading level0 col7" >Bias</th>
#       <th id="T_169a1_level0_col8" class="col_heading level0 col8" >RMAD</th>
#       <th id="T_169a1_level0_col9" class="col_heading level0 col9" >RMSE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CATEGORIES</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_169a1_level0_row0" class="row_heading level0 row0" >ML FORECAST APARTMENT, FLAT</th>
#       <td id="T_169a1_row0_col0" class="data row0 col0" >8,465,579</td>
#       <td id="T_169a1_row0_col1" class="data row0 col1" >8,273,173</td>
#       <td id="T_169a1_row0_col2" class="data row0 col2" >0.0%</td>
#       <td id="T_169a1_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_169a1_row0_col4" class="data row0 col4" >159,727.91</td>
#       <td id="T_169a1_row0_col5" class="data row0 col5" >156,097.61</td>
#       <td id="T_169a1_row0_col6" class="data row0 col6" >-3,630.31</td>
#       <td id="T_169a1_row0_col7" class="data row0 col7" >-0.02</td>
#       <td id="T_169a1_row0_col8" class="data row0 col8" >4.1%</td>
#       <td id="T_169a1_row0_col9" class="data row0 col9" >9,919.73</td>
#     </tr>
#     <tr>
#       <th id="T_169a1_level0_row1" class="row_heading level0 row1" >BASELINE APARTMENT, FLAT</th>
#       <td id="T_169a1_row1_col0" class="data row1 col0" >8,465,579</td>
#       <td id="T_169a1_row1_col1" class="data row1 col1" >8,172,150</td>
#       <td id="T_169a1_row1_col2" class="data row1 col2" >0.0%</td>
#       <td id="T_169a1_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_169a1_row1_col4" class="data row1 col4" >159,727.91</td>
#       <td id="T_169a1_row1_col5" class="data row1 col5" >154,191.51</td>
#       <td id="T_169a1_row1_col6" class="data row1 col6" >-5,536.40</td>
#       <td id="T_169a1_row1_col7" class="data row1 col7" >-0.03</td>
#       <td id="T_169a1_row1_col8" class="data row1 col8" >4.9%</td>
#       <td id="T_169a1_row1_col9" class="data row1 col9" >10,412.86</td>
#     </tr>
#     <tr>
#       <th id="T_169a1_level0_row2" class="row_heading level0 row2" >ML FORECAST APARTMENT, FURNISHED_FLAT</th>
#       <td id="T_169a1_row2_col0" class="data row2 col0" >1,149,668</td>
#       <td id="T_169a1_row2_col1" class="data row2 col1" >1,178,017</td>
#       <td id="T_169a1_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_169a1_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_169a1_row2_col4" class="data row2 col4" >21,691.85</td>
#       <td id="T_169a1_row2_col5" class="data row2 col5" >22,226.73</td>
#       <td id="T_169a1_row2_col6" class="data row2 col6" >534.89</td>
#       <td id="T_169a1_row2_col7" class="data row2 col7" >0.02</td>
#       <td id="T_169a1_row2_col8" class="data row2 col8" >7.4%</td>
#       <td id="T_169a1_row2_col9" class="data row2 col9" >2,061.25</td>
#     </tr>
#     <tr>
#       <th id="T_169a1_level0_row3" class="row_heading level0 row3" >BASELINE APARTMENT, FURNISHED_FLAT</th>
#       <td id="T_169a1_row3_col0" class="data row3 col0" >1,149,668</td>
#       <td id="T_169a1_row3_col1" class="data row3 col1" >1,207,660</td>
#       <td id="T_169a1_row3_col2" class="data row3 col2" >0.0%</td>
#       <td id="T_169a1_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_169a1_row3_col4" class="data row3 col4" >21,691.85</td>
#       <td id="T_169a1_row3_col5" class="data row3 col5" >22,786.04</td>
#       <td id="T_169a1_row3_col6" class="data row3 col6" >1,094.19</td>
#       <td id="T_169a1_row3_col7" class="data row3 col7" >0.05</td>
#       <td id="T_169a1_row3_col8" class="data row3 col8" >8.1%</td>
#       <td id="T_169a1_row3_col9" class="data row3 col9" >2,383.06</td>
#     </tr>
#     <tr>
#       <th id="T_169a1_level0_row4" class="row_heading level0 row4" >ML FORECAST APARTMENT, ROOF_FLAT</th>
#       <td id="T_169a1_row4_col0" class="data row4 col0" >489,494</td>
#       <td id="T_169a1_row4_col1" class="data row4 col1" >460,441</td>
#       <td id="T_169a1_row4_col2" class="data row4 col2" >0.0%</td>
#       <td id="T_169a1_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_169a1_row4_col4" class="data row4 col4" >9,413.35</td>
#       <td id="T_169a1_row4_col5" class="data row4 col5" >8,854.63</td>
#       <td id="T_169a1_row4_col6" class="data row4 col6" >-558.72</td>
#       <td id="T_169a1_row4_col7" class="data row4 col7" >-0.06</td>
#       <td id="T_169a1_row4_col8" class="data row4 col8" >9.7%</td>
#       <td id="T_169a1_row4_col9" class="data row4 col9" >1,278.22</td>
#     </tr>
#     <tr>
#       <th id="T_169a1_level0_row5" class="row_heading level0 row5" >BASELINE APARTMENT, ROOF_FLAT</th>
#       <td id="T_169a1_row5_col0" class="data row5 col0" >489,494</td>
#       <td id="T_169a1_row5_col1" class="data row5 col1" >476,850</td>
#       <td id="T_169a1_row5_col2" class="data row5 col2" >0.0%</td>
#       <td id="T_169a1_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_169a1_row5_col4" class="data row5 col4" >9,413.35</td>
#       <td id="T_169a1_row5_col5" class="data row5 col5" >9,170.19</td>
#       <td id="T_169a1_row5_col6" class="data row5 col6" >-243.15</td>
#       <td id="T_169a1_row5_col7" class="data row5 col7" >-0.03</td>
#       <td id="T_169a1_row5_col8" class="data row5 col8" >11.0%</td>
#       <td id="T_169a1_row5_col9" class="data row5 col9" >1,466.38</td>
#     </tr>
#   </tbody>
# </table>

# %%
tsp.plot_weekly_per_agg(df_evl,actuals_col='PRICE',var_cols=['BASELINE','ML FORECAST'], agg_col='CATEGORIES', 
                           agg='mean', limit_n_plots=10, title_text='',
                          date_from='2021-01-01',date_upto='2021-12-31',plot_two_years_ago=False,plot_last_year=True)
# Out:
# alt.ConcatChart(...)
# alt.ConcatChart(...)
# alt.ConcatChart(...)
# alt.ConcatChart(...)
# alt.ConcatChart(...)
# alt.ConcatChart(...)
# alt.ConcatChart(...)
# alt.ConcatChart(...)
# alt.ConcatChart(...)
